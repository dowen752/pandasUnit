# %% [markdown]
# # Pandas Basics Part 3 — Workbook

# %% [markdown]
# ___

# %% [markdown]
# ## Dataset
# ### *The Pudding*'s Film Dialogue Data

# %% [markdown]
# The dataset that we're working with in this lesson is taken from Hannah Andersen and Matt Daniels's *Pudding* essay, ["Film Dialogue from 2,000 screenplays, Broken Down by Gender and Age"](https://pudding.cool/2017/03/film-dialogue/). The dataset provides information about 2,000 films from 1925 to 2015, including characters’ names, genders, ages, how many words each character spoke in each film, the release year of each film, and how much money the film grossed. They included character gender information because they wanted to contribute data to a broader conversation about how "white men dominate movie roles."

# %% [markdown]
# ___

# %% [markdown]
# ## Import Pandas

# %% [markdown]
# To use the Pandas library, we first need to `import` it.

# %%
import pandas as pd

# %% [markdown]
# ## Change Display Settings

# %% [markdown]
# By default, Pandas will display 60 rows and 20 columns. I often change [Pandas' default display settings](https://pandas.pydata.org/pandas-docs/stable/user_guide/options.html) to show more rows or columns.

# %%
pd.options.display.max_rows = 200

# %% [markdown]
# ## Get Data

# %%
film_df = pd.read_csv('Pudding-Film-Dialogue-Clean.csv', delimiter=",", encoding='utf-8')

# %% [markdown]
# This creates a Pandas [DataFrame object](https://pandas.pydata.org/pandas-docs/stable/user_guide/dsintro.html#DataFrame) — often abbreviated as *df*, e.g., *slave_voyages_df*. A DataFrame looks and acts a lot like a spreadsheet. But it has special powers and functions that we will discuss in the next few lessons.

# %% [markdown]
# ## Overview
#
# To look at a random *n* number of rows in a DataFrame, we can use a method called `.sample()`.

# %%
film_df.sample(10)
# Out:
#                         title  release_year        character gender  words  \
# 19412             Unstoppable          2010             Will    man   1003
# 16949            The Smurfs 2          2013            Odile  woman    130
# 1054                Eagle Eye          2008            Scott    man   1150
# 19379          Into the Night          1985  Beverly Wilshir    man    125
# 10325             The Shining          1980  Overlook Hotel     man    362
# 19334                 Deja Vu          2006      Doug Carlin    man   6670
# 14922        Some Like It Hot          1959          Bellhop    man    145
# 17167  No Country for Old Men          2007     Ins Official    man    145
# 21551       Kingdom of Heaven          2005  Guy De Lusignan    man    742
# 16648         The Jungle Book          1967  King Louie Of T    man    231
#
#        proportion_of_dialogue   age   gross  script_id
# 19412                0.122005  30.0    89.0       7427
# 16949                0.017811   NaN    75.0       6060
# 1054                 0.126582   NaN   122.0        879
# 19379                0.032076  47.0    16.0       7424
# 10325                0.019294  22.0     NaN       3325
# 19334                0.440642  52.0    85.0       7386
# 14922                0.009698   NaN   426.0       4990
# 17167                0.017428  55.0    93.0       6150
# 21551                0.100515  39.0    64.0       8382
# 16648                0.031963  57.0  1029.0       5534

# %% [markdown]
# Generate information about all the columns in the data

# %%
film_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23047 entries, 0 to 23046
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   title                   23047 non-null  object
#  1   release_year            23047 non-null  int64
#  2   character               23047 non-null  object
#  3   gender                  23047 non-null  object
#  4   words                   23047 non-null  int64
#  5   proportion_of_dialogue  23047 non-null  float64
#  6   age                     18262 non-null  float64
#  7   gross                   19386 non-null  float64
#  8   script_id               23047 non-null  int64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 1.6+ MB

# %% [markdown]
# Just like Python has different data types, Pandas has different data types, too. These data types are automatically assigned to columns when we read in a CSV file. We can check these Pandas data types with the [`.dtypes` method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dtypes.html).

# %% [markdown]
# | **Pandas Data Type** |  **Explanation**                                                                                   |
# |:-------------:|:---------------------------------------------------------------------------------------------------:|
# | `object`         | string                                                                               |
# | `float64`         | float                                               |
# | `int64`       | integer                                                        |
# | `datetime64`       |  date time

# %% [markdown]
# Make a histogram of the DataFrame

# %%
film_df.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'release_year'}>,
#         <Axes: title={'center': 'words'}>],
#        [<Axes: title={'center': 'proportion_of_dialogue'}>,
#         <Axes: title={'center': 'age'}>],
#        [<Axes: title={'center': 'gross'}>,
#         <Axes: title={'center': 'script_id'}>]], dtype=object)

# %% [markdown]
# Generate descriptive statistics for all the columns in the data

# %%
film_df.describe(include='all')

# %% [markdown]
# ### ❓ What patterns or outliers do you notice?

# %% [markdown]
# ## Drop Rows

# %%
film_df[film_df['age'] > 100]
# Out:
#                                 title  release_year        character gender  \
# 4024                  American Psycho          2000    Harold Carnes    man
# 5254                          Case 39          2009  Margaret Sulliv  woman
# 5370                            Chaos          2005     Bernie Callo    man
# 5950                     The Departed          2006          Realtor    man
# 6899                       Get Carter          2000          Thorpey    man
# 7787                    Into the Wild          2007             Bull    man
# 7968   Jay and Silent Bob Strike Back          2001  Silent Bob'S Mo  woman
# 9233                Never Been Kissed          1999      Monty Malik    man
# 9617                        The Piano          1993           Nessie  woman
# 9819                      Raging Bull          1980         Reporter    man
# 10151                           Se7en          1995    Officer Davis    man
# 13600                    Knight Moves          1992       Newscaster    man
# 14384                        Only You          1994  Himself       (    man
# 14757                          Scream          1996  Girl In Bathroo  woman
# 19221                      Borderland          2007  Captain Ramirez    man
# 21634               Last Man Standing          1996      Jack Mccool    man
#
#        words  proportion_of_dialogue     age  gross  script_id
# 4024     434                0.025271  2000.0   24.0       1639
# 5254     310                0.037944  2009.0   15.0       1962
# 5370     244                0.015051  2005.0    NaN       1985
# 5950     148                0.005575  2006.0  175.0       2144
# 6899     133                0.026552  2000.0   24.0       2380
# 7787     188                0.009936  2007.0   23.0       2625
# 7968     224                0.009292  2001.0   46.0       2673
# 9233     104                0.005219  1999.0   95.0       2986
# 9617     116                0.012262  1993.0   84.0       3095
# 9819     300                0.013364  1980.0    NaN       3169
# 10151    152                0.007366  1995.0  200.0       3288
# 13600    120                0.012451  1992.0    1.0       4487
# 14384    276                0.023730   102.0   41.0       4758
# 14757    162                0.018510  1996.0  202.0       4920
# 19221    121                0.017430  2007.0    NaN       7351
# 21634    338                0.044491  1996.0   35.0       8412

# %% [markdown]
# If you want to double check, you can examine the [data that the Pudding shared here](https://github.com/matthewfdaniels/scripts/blob/graphs/character_list5.csv) (you can control + F to search for specific characters).

# %%
film_df = film_df.drop(film_df[film_df['age'] > 100].index)

# %%
film_df
# Out:
#                                title  release_year        character gender  \
# 0      The Bridges of Madison County          1995            Betty  woman
# 1      The Bridges of Madison County          1995  Carolyn Johnson  woman
# 2      The Bridges of Madison County          1995          Eleanor  woman
# 3      The Bridges of Madison County          1995  Francesca Johns  woman
# 4      The Bridges of Madison County          1995            Madge  woman
# ...                              ...           ...              ...    ...
# 23042           Beauty and the Beast          1991          Lumiere    man
# 23043           Beauty and the Beast          1991          Maurice    man
# 23044           Beauty and the Beast          1991  Monsieur D'Arqu    man
# 23045           Beauty and the Beast          1991       Mrs. Potts  woman
# 23046           Beauty and the Beast          1991         Wardrobe  woman
#
#        words  proportion_of_dialogue   age  gross  script_id
# 0        311                0.048639  35.0  142.0        280
# 1        873                0.136534   NaN  142.0        280
# 2        138                0.021583   NaN  142.0        280
# 3       2251                0.352049  46.0  142.0        280
# 4        190                0.029715  46.0  142.0        280
# ...      ...                     ...   ...    ...        ...
# 23042   1063                0.104636  56.0  452.0       9254
# 23043   1107                0.108967  71.0  452.0       9254
# 23044    114                0.011222  58.0  452.0       9254
# 23045    564                0.055517  66.0  452.0       9254
# 23046    121                0.011911  54.0  452.0       9254
#
# [23031 rows x 9 columns]

# %%
film_df[film_df['age'] > 100]
# Out:
# Empty DataFrame
# Columns: [title, release_year, character, gender, words, proportion_of_dialogue, age, gross, script_id]
# Index: []

# %% [markdown]
# ## Rename Columns

# %%
film_df = film_df.rename(columns={'imdb_character_name': 'character', 'year': 'release_year'})

# %%
film_df.head()

# %% [markdown]
# ## Filter

# %% [markdown]
# <div class="admonition note" name="html-admonition" style="background: lightblue; padding: 10px">
# Group work!
# </div>

# %% [markdown]
# Find a specific film that you're intersted and then filter the DataFrame for only rows relevant to that film.
#
# If you want to search for films by decade and genre, you can [search the with the Pudding's handy data viz here](https://pudding.cool/2017/03/film-dialogue/embed.html).

# %%
film_filter = ...

# %% [markdown]
# If you want to sort by characters who speak the most, feel free to add `.sort_values(by='words', ascending=False)`

# %%
film_df[film_filter]

# %% [markdown]
# Now pick a character from this film (or another character) and filter the DataFrame by character.

# %%
character_filter = film_df["character"] == "Betty" # same thing but one line film_df[film_df["character"] == "Betty"]

# %%
film_df[character_filter]
# Out:
#                                title  release_year character gender  words  \
# 0      The Bridges of Madison County          1995     Betty  woman    311
# 4791             Blast from the Past          1999     Betty  woman    158
# 6599                      Four Rooms          1995     Betty  woman   2040
# 7026               Gods and Monsters          1998     Betty  woman    892
# 9108                Mulholland Drive          2001     Betty  woman   5088
# 11827                        28 Days          2000     Betty  woman    109
# 14288                   No One Lives          2012     Betty  woman    297
# 14464          The Ploughman's Lunch          1983     Betty  woman    116
#
#        proportion_of_dialogue   age  gross  script_id
# 0                    0.048639  35.0  142.0        280
# 4791                 0.006667   NaN   45.0       1853
# 6599                 0.077833  35.0    8.0       2311
# 7026                 0.038389  37.0   11.0       2419
# 9108                 0.370575  33.0   11.0       2962
# 11827                0.045341  49.0   59.0       3784
# 14288                0.062434  30.0    NaN       4716
# 14464                0.012238   NaN    NaN       4804

# %% [markdown]
# ### ❓ How does this data align with your experience/knowledge of the film?
# ### ❓ How do these specific examples influence your thoughts about the data collection and categorization process? What would you have done differently (if anything)?

# %% [markdown]
# ## Sort Values

# %% [markdown]
# <div class="admonition note" name="html-admonition" style="background: lightblue; padding: 10px">
# Group work!
# </div>

# %% [markdown]
# Sort the DataFrame from the character who has the highest `proportion_of_dialogue` to the lowest.  Then examine the first 20 rows with `.head(20)` or `[:20]`.

# %%
film_df.sort_values(by="proportion_of_dialogue", ascending = False).head(20)
# Out:
#                              title  release_year        character gender  \
# 7242                    Happy Feet          2006           Mumble    man
# 16371          The End of the Tour          2015     David Lipsky    man
# 21092                         Duel          1971       David Mann    man
# 3650                     127 Hours          2010     Aron Ralston    man
# 22236                        Alfie          2004            Alfie    man
# 21663                   Mala Noche          1986             Walt    man
# 1019                     Duck Soup          1933          Groucho    man
# 4569         The Battle of Algiers          1966     Col. Mathieu    man
# 17750                         1408          2007      Mike Enslin    man
# 18138           Jumpin' Jack Flash          1986   Terry Dolittle  woman
# 6083   The Distinguished Gentleman          1992      Tommy Boggs    man
# 4300              Army of Darkness          1992              Ash    man
# 626                      Cast Away          2000     Chuck Noland    man
# 1208                        Fletch          1985  Irwin 'Fletch'     man
# 21749               Unlawful Entry          1992  Officer Pete Da    man
# 890                      Deception          2008  Jonathan Mcquar    man
# 18422              The Weather Man          2005  Dave'S Archery     man
# 13273                      Hot Rod          2007       Rod Kimble    man
# 8581                   Lord of War          2005       Yuri Orlov    man
# 11638      The Wolf of Wall Street          2013   Jordan Belfort    man
#
#        words  proportion_of_dialogue   age  gross  script_id
# 7242    2677                0.923422  25.0  262.0       2483
# 16371   3117                0.911137  32.0    3.0       5485
# 21092   2660                0.881086  47.0    NaN       8164
# 3650    4336                0.842760  32.0   20.0       1520
# 22236   5852                0.814815  32.0   18.0       8683
# 21663   2093                0.810612   NaN    NaN       8423
# 1019    3697                0.730344   NaN    NaN        873
# 4569    4962                0.723113  44.0    6.0       1780
# 17750   2338                0.703581  41.0   91.0       6537
# 18138   4722                0.699452  31.0   60.0       6798
# 6083    1044                0.698795   NaN   97.0       2160
# 4300    4466                0.695639  34.0   24.0       1696
# 626     4034                0.692770  44.0  377.0        789
# 1208    4237                0.689953  42.0  114.0        917
# 21749   3637                0.689087  38.0  119.0       8484
# 890     5875                0.688181  37.0    5.0        851
# 18422   6476                0.687692   NaN   16.0       6930
# 13273   8538                0.687052  29.0   17.0       4373
# 8581   13478                0.686253  41.0   32.0       2804
# 11638  11718                0.683186  39.0  125.0       3737

# %% [markdown]
# Sort the DataFrame from the character who has the lowest `proportion_of_dialogue` to the highest. Then examine the first 20 rows with `.head(20)` or `[:20]`.

# %%
film_df.sort_values(by="proportion_of_dialogue", ascending = True).head(20)
# Out:
#              title  release_year        character gender  words  \
# 5283        Casino          1995   Piscano'S Wife  woman    104
# 5272        Casino          1995  Frankie Avalon     man    106
# 5291        Casino          1995    Vinny Forlano    man    112
# 5262        Casino          1995          Cashier  woman    114
# 5277        Casino          1995        La Banker    man    114
# 5292        Casino          1995           Winner    man    116
# 5286        Casino          1995   Security Guard    man    116
# 8031           JFK          1991     Prison Guard    man    106
# 5258        Casino          1995       Anna Scott  woman    124
# 5257        Casino          1995  Amy Rothstein (  woman    130
# 8013           JFK          1991       J.C. Price    man    114
# 5260        Casino          1995    Bartender Joe    man    132
# 5268        Casino          1995  Dominick Santor    man    132
# 5264        Casino          1995  Chastised Deale    man    142
# 5267        Casino          1995        Detective    man    150
# 8035           JFK          1991  Virginia Garris  woman    134
# 6802  Funny People          2009  Boyfriend Of Ta    man    106
# 8027           JFK          1991     Mr. Goldberg    man    146
# 8017           JFK          1991  Jasper Garrison    man    148
# 8661      Magnolia          1999             Luis    man    108
#
#       proportion_of_dialogue   age  gross  script_id
# 5283                0.001537   NaN   84.0       1963
# 5272                0.001566  56.0   84.0       1963
# 5291                0.001655   NaN   84.0       1963
# 5262                0.001684   NaN   84.0       1963
# 5277                0.001684  61.0   84.0       1963
# 5292                0.001714   NaN   84.0       1963
# 5286                0.001714  55.0   84.0       1963
# 8031                0.001802   NaN  145.0       2682
# 5258                0.001832   NaN   84.0       1963
# 5257                0.001921   NaN   84.0       1963
# 8013                0.001938  73.0  145.0       2682
# 5260                0.001950   NaN   84.0       1963
# 5268                0.001950  47.0   84.0       1963
# 5264                0.002098   NaN   84.0       1963
# 5267                0.002216   NaN   84.0       1963
# 8035                0.002278   NaN  145.0       2682
# 6802                0.002416  29.0   60.0       2352
# 8027                0.002482  52.0  145.0       2682
# 8017                0.002516   7.0  145.0       2682
# 8661                0.002603  43.0   38.0       2821

# %% [markdown]
# Sort the DataFrame from the character who speaks the least number of `words` to the character who speaks the most number of words. Then examine the first 20 rows with `.head(20)` or `[:20]`.

# %%
film_df.sort_values(by=["words", "proportion_of_dialogue"], ascending = False).head(20)
# Out:
#                                 title  release_year        character gender  \
# 8019                              JFK          1991              Jim    man
# 5285                           Casino          1995  Sam 'Ace' Roths    man
# 7403                    High Fidelity          2000       Rob Gordon    man
# 9372               Observe and Report          2009           Ronnie    man
# 5279                           Casino          1995    Nicky Santoro    man
# 7075                      Gran Torino          2008    Walt Kowalski    man
# 3916                           Amelia          2009   Amelia Earhart  woman
# 3733                   A Few Good Men          1992  Lt. Daniel Kaff    man
# 6808                     Funny People          2009   George Simmons    man
# 11758                 Youth in Revolt          2009       Nick Twisp    man
# 4009           The American President          1995  President Andre    man
# 6513   Fear and Loathing in Las Vegas          1998       Raoul Duke    man
# 6429                   The Family Man          2000    Jack Campbell    man
# 14284                           Nixon          1995  Richard M. Nixo    man
# 6630                         Fracture          2007    Willy Beachum    man
# 6810                     Funny People          2009       Ira Wright    man
# 8581                      Lord of War          2005       Yuri Orlov    man
# 4196                    The Apartment          1960      C.C. Baxter    man
# 9816                      Raging Bull          1980    Jake La Motta    man
# 387                      Barry Lyndon          1975         Roderick    man
#
#        words  proportion_of_dialogue   age  gross  script_id
# 8019   28102                0.477665  36.0  145.0       2682
# 5285   26798                0.395963  52.0   84.0       1963
# 7403   24376                0.589020  34.0   44.0       2536
# 9372   19892                0.580585  27.0   27.0       3027
# 5279   19576                0.289252  52.0   84.0       1963
# 7075   17440                0.527016  78.0  179.0       2436
# 3916   16164                0.527615  35.0   16.0       1613
# 3733   16148                0.381407  30.0  295.0       1538
# 6808   15708                0.358025  43.0   60.0       2352
# 11758  14794                0.437563  21.0   17.0       3765
# 4009   14642                0.415919  51.0  130.0       1637
# 6513   14490                0.594681  35.0   19.0       2276
# 6429   14214                0.483305  36.0  122.0       2263
# 14284  14086                0.542040  58.0   27.0       4711
# 6630   13874                0.571229  27.0   49.0       2314
# 6810   13556                0.308976  27.0   60.0       2352
# 8581   13478                0.686253  41.0   32.0       2804
# 4196   13294                0.422488  35.0    NaN       1673
# 9816   13226                0.589184  37.0    NaN       3169
# 387    12487                0.606371   NaN    NaN        716

# %% [markdown]
# ### ❓ What patterns do you notice here? What surprises you or doesn't surprise you?

# %% [markdown]
# ## Groupby

# %% [markdown]
# Group by film and then calculate the sum total for every column.

# %%
film_df.groupby("title").sum()
# Out:
#                             release_year  \
# title
# (500) Days of Summer               26117
# 10 Things I Hate About You         23988
# 12 Years a Slave                   56364
# 12 and Holding                     30075
# 127 Hours                           8040
# ...                                  ...
# Zero Effect                        13986
# Zerophilia                         16040
# Zodiac                             62217
# eXistenZ                           17991
# xXx                                18018
#
#                                                                     character  \
# title
# (500) Days of Summer        AlisonAutumn - Girl ACo-Worker 3DoucheManMcken...
# 10 Things I Hate About You  Bianca StratforCameron JamesChastityDerekJoey ...
# 12 Years a Slave            Anne NorthupArmsbyBassBrownBurchCelesteChapinC...
# 12 and Holding              Ashley CargesCoach GilmoreDoctorGrace FisherGu...
# 127 Hours                                         Aron RalstonKristiMeganRana
# ...                                                                       ...
# Zero Effect                 Basketball PlayDaisyDaryl ZeroGloria SullivanG...
# Zerophilia                        JanineJeremyKeenanLucaLukeMaxMichelleSydney
# Zodiac                      Al HymanArthur Leigh AlBelli'S HousekeBob Vaug...
# eXistenZ                    Allegra GellerChinese WaiterD'Arcy NaderGasKir...
# xXx                         Agent Augustus El JefeJames TannickMilan SovaT...
#
#                                                                        gender  \
# title
# (500) Days of Summer        womanwomanmanmanmanmanmanmanwomanwomanwomanmanman
# 10 Things I Hate About You       womanmanwomanmanmanwomanwomanmanmanmanmanman
# 12 Years a Slave            womanmanmanmanmanwomanmanmanmanwomanmanmanmanm...
# 12 and Holding              womanmanmanwomanmanmanmanmanmanmanwomanmanwoma...
# 127 Hours                                                  manwomanwomanwoman
# ...                                                                       ...
# Zero Effect                                       manwomanmanwomanmanwomanman
# Zerophilia                                     womanmanmanwomanmanmanwomanman
# Zodiac                      manmanwomanmanmanmanmanwomanwomanwomanmanmanma...
# eXistenZ                                      womanmanmanmanmanwomanmanmanman
# xXx                                             manmanmanmanmanmanmanwomanman
#
#                             words  proportion_of_dialogue     age   gross  \
# title
# (500) Days of Summer        18500                     1.0   378.0   481.0
# 10 Things I Hate About You  19680                     1.0   307.0   780.0
# 12 Years a Slave            19628                     1.0   712.0  1680.0
# 12 and Holding              15968                     1.0   513.0     0.0
# 127 Hours                    5145                     1.0   114.0    80.0
# ...                           ...                     ...     ...     ...
# Zero Effect                 13927                     1.0   227.0    21.0
# Zerophilia                  16686                     1.0   160.0     0.0
# Zodiac                      14656                     1.0  1071.0  1271.0
# eXistenZ                     9447                     1.0   309.0    36.0
# xXx                          8285                     1.0   283.0  1899.0
#
#                             script_id
# title
# (500) Days of Summer            19942
# 10 Things I Hate About You      18144
# 12 Years a Slave                42476
# 12 and Holding                  22710
# 127 Hours                        6080
# ...                               ...
# Zero Effect                     57106
# Zerophilia                      30144
# Zodiac                         201221
# eXistenZ                        62757
# xXx                             13473
#
# [1994 rows x 8 columns]

# %% [markdown]
# Group by film, isolate the `words` column, and then calculate the sum total for every column.

# %%
film_df.groupby('title')['words'].sum()
# Out:
# title
# (500) Days of Summer          18500
# 10 Things I Hate About You    19680
# 12 Years a Slave              19628
# 12 and Holding                15968
# 127 Hours                      5145
#                               ...
# Zero Effect                   13927
# Zerophilia                    16686
# Zodiac                        14656
# eXistenZ                       9447
# xXx                            8285
# Name: words, Length: 1994, dtype: int64

# %%
film_df.groupby...

# %% [markdown]
# ## Filter, Then Groupby

# %% [markdown]
# <div class="admonition note" name="html-admonition" style="background: lightblue; padding: 10px">
# Group work!
# </div>

# %% [markdown]
# Filter the DataFrame for only characters labeled as `woman`

# %%
film_filter = film_df['release_year'] == 1990

# %%
film_df[film_filter]
# Out:
#                 title  release_year        character gender  words  \
# 299        Awakenings          1990          Anthony    man    191
# 300        Awakenings          1990      Dr. Kaufman    man    762
# 301        Awakenings          1990  Dr. Malcolm Say    man   4998
# 302        Awakenings          1990         Fernando    man    112
# 303        Awakenings          1990           Hector    man    228
# ...               ...           ...              ...    ...    ...
# 20994  Bird on a Wire          1990             Earl    man    168
# 20995  Bird on a Wire          1990  Marianne Graves  woman    963
# 20996  Bird on a Wire          1990             Neff    man    105
# 20997  Bird on a Wire          1990    Rachel Varney  woman    163
# 20998  Bird on a Wire          1990      Rick Jarmin    man   1383
#
#        proportion_of_dialogue   age  gross  script_id
# 299                  0.016023  28.0  107.0        706
# 300                  0.063926  45.0  107.0        706
# 301                  0.419295  39.0  107.0        706
# 302                  0.009396   NaN  107.0        706
# 303                  0.019128   NaN  107.0        706
# ...                       ...   ...    ...        ...
# 20994                0.056206   NaN  146.0       8095
# 20995                0.322181  45.0  146.0       8095
# 20996                0.035129   NaN  146.0       8095
# 20997                0.054533  32.0  146.0       8095
# 20998                0.462697  34.0  146.0       8095
#
# [369 rows x 9 columns]

# %% [markdown]
# Filter the DataFrame for only characters labeled as `man`

# %%
men_filter = film_df['gender'] == 'man'

# %%
men_film_df = film_df[men_filter]

# %% [markdown]
# Now group `women_film_df` by film, isolate the `words` column, and sum the `words` spoken by women.

# %%
film_df[film_filter].groupby('title')['title'].value_counts()
# Out:
# title
# Awakenings                         15
# Back to the Future Part III         9
# Bird on a Wire                      6
# Come See the Paradise              12
# Dances with Wolves                 19
# Days of Thunder                    11
# Die Hard 2                         16
# Edward Scissorhands                10
# Ghost                               9
# Goodfellas                         12
# Gremlins 2: The New Batch          13
# Hard to Kill                        8
# Hardware                            7
# Home Alone                          6
# Jacob's Ladder                     11
# Memphis Belle                      13
# Misery                              6
# My Blue Heaven                      3
# Narrow Margin                       9
# Predator 2                         10
# Pretty Woman                        6
# Revenge                            12
# Rocky V                             6
# The Adventures of Ford Fairlane    11
# The Bonfire of the Vanities        21
# The Grifters                       12
# The Hunt for Red October           24
# The Rescuers Down Under            14
# To Sleep with Anger                15
# Total Recall                       12
# Tremors                            13
# Wild at Heart                      18
# Name: count, dtype: int64

# %% [markdown]
# Assign this Series to a new variable `women_by_film`

# %%
women_by_film = women_film_df.groupby('title')['words'].sum()
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# Cell In[4], line 1
#
# ----> 1 women_by_film = women_film_df.groupby('title')['words'].sum()
#
#
#
# NameError: name 'women_film_df' is not defined

# %% [markdown]
# Using the same construction, make a new another new variable `men_by_film`

# %%
men_by_film = men_film_df.groupby('title')['words'].sum()

# %% [markdown]
# Sort `women_by_film` from the film with the most words to the film with the least words. Then examine the top 20 values.

# %%
women_by_film.sort_values(ascending=False)[:20]
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# Cell In[3], line 1
#
# ----> 1 women_by_film.sort_values(ascending=False)[:20]
#
#
#
# NameError: name 'women_by_film' is not defined

# %% [markdown]
# Assign this sorted list of movies to the variable `top20_women`

# %%
top20_women = women_by_film.sort_values(ascending=False)[:20]

# %% [markdown]
# Using the same construction, make a new variable `top20_men`

# %%
top20_men = men_by_film.sort_values(ascending=False)[:20]

# %% [markdown]
# ### ❓ What patterns do you notice here? What surprises you or doesn't surprise you?

# %% [markdown]
# ## Saving Plots

# %% [markdown]
# <div class="admonition note" name="html-admonition" style="background: lightblue; padding: 10px">
# Group work!
# </div>

# %% [markdown]
# Make a bar chart of `top20_women`. Give the chart a title, and specify a color.

# %%
top20_women.plot(kind='bar')

# %% [markdown]
# To save the plot, you can use `ax.figure.savefig()` and the name of the file in quotation marks.

# %%
ax = top20_women.plot(kind='bar')
ax.figure.savefig('top20_women.png')

# %% [markdown]
# Look in the file browser on the left and double click the PNG file. How does it look? Uh oh!
#
# Sometimes parts of a plot will get cut off when you save it. To fix this issue, you can use a function from the Matplotlib library called `plt.tight_layout()`, which will adjust the plot before you save it.
#
# To use this function, you need to `import matplotlib.pyplot as plt`.

# %%
import matplotlib.pyplot as plt

ax = top20_women.plot(kind='bar')
plt.tight_layout()
ax.figure.savefig('top20_women.png')

# %% [markdown]
# ## Scatter Plots and Line Plots

# %% [markdown]
# Let's make a scatter plot that shows how many words women and men speak based on their age.

# %%
women_film_df.groupby('age')['words'].sum().reset_index()
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# Cell In[2], line 1
#
# ----> 1 women_film_df.groupby('age')['words'].sum().reset_index()
#
#
#
# NameError: name 'women_film_df' is not defined

# %%
women_age_words = women_film_df.groupby('age')['words'].sum().reset_index()
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# Cell In[1], line 1
#
# ----> 1 women_age_words = women_film_df.groupby('age')['words'].sum().reset_index()
#
#
#
# NameError: name 'women_film_df' is not defined

# %%
men_age_words = men_film_df.groupby('age')['words'].sum().reset_index()

# %%
ax = women_age_words.plot(kind='scatter', x='age', y='words', color='red')
men_age_words.plot(ax=ax, kind='scatter', x='age', y='words', color='blue')

# %% [markdown]
# Now let's make a line plot of the exact same data. Copy and paste the code in the cell above and change it to produce a line plot instead of a scatter plot.

# %% [markdown]
# <div class="admonition note" name="html-admonition" style="background: lightblue; padding: 10px">
# Group work!
# </div>

# %%
# Your code here
# Your code here
